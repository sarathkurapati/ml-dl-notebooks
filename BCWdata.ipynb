# %% [markdown]
# <a href="https://colab.research.google.com/github/sarathkurapati/ml-dl-notebooks/blob/main/BCWdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("BCWdata.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.drop(columns=["Unnamed: 32","id"],axis=1,inplace=True)

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.diagnosis=le.fit_transform(df.diagnosis)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
x=df.drop(columns="diagnosis",axis=1)
y=df.diagnosis

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#initializing the object
classification_model=Sequential()

# %%
#building an ann model for classification
#input layer  
classification_model.add(Dense(30,activation="relu"))
#hidden layers------->
classification_model.add(Dense(64,activation="relu"))
classification_model.add(Dense(36,activation="relu"))
classification_model.add(Dense(16,activation="relu"))
classification_model.add(Dense(10,activation="relu"))
#output layer
classification_model.add(Dense(1,activation="sigmoid"))

# %%
classification_model.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
classification_model.fit(x_train,y_train,batch_size=8,epochs=400,validation_data=(x_test,y_test))
# Out:
# Epoch 1/400
# 57/57 [==============================] - 2s 8ms/step - loss: 3.0907 - accuracy: 0.5802 - val_loss: 0.4987 - val_accuracy: 0.8596
# Epoch 2/400
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.8879 - val_loss: 0.4090 - val_accuracy: 0.8596
# Epoch 3/400
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.8703 - val_loss: 0.3275 - val_accuracy: 0.8860
# Epoch 4/400
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3214 - accuracy: 0.8857 - val_loss: 0.3797 - val_accuracy: 0.8070
# Epoch 5/400
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2876 - accuracy: 0.9011 - val_loss: 0.2826 - val_accuracy: 0.9035
# Epoch 6/400
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2748 - accuracy: 0.8945 - val_loss: 0.2599 - val_accuracy: 0.9211
# Epoch 7/400
# ...

# %%
y_pred=classification_model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
y_pred
# Out:
# array([[9.2409587e-01],
#        [2.0779429e-03],
#        [2.6902386e-05],
#        [3.5556180e-03],
#        [4.7239242e-05],
#        [2.7082833e-06],
#        [4.1198850e-06],
#        [3.9547254e-07],
#        [1.8276566e-03],
#        [3.4617906e-07],
#        [3.5489779e-02],
#        [1.9628881e-02],
#        [1.3356954e-06],
#        [4.5415249e-01],
#        [6.0140938e-03],
#        [4.8122203e-01],
#        [6.8501820e-04],
#        [9.9999946e-01],
#        [9.9973851e-01],
#        [9.9999988e-01],
#        [9.9999988e-01],
#        [2.2138216e-01],
#        [2.3194984e-06],
#        [6.0138762e-05],
#        [9.9611008e-01],
#        [7.7702578e-05],
#        [2.4679957e-06],
#        [1.5816191e-01],
#        [5.6611025e-06],
#        [1.0000000e+00],
#        [8.1286707e-06],
#        [9.9996144e-01],
#        [3.3855110e-03],
#        [9.2524636e-01],
#        [1.2098941e-07],
#        [9.9999088e-01],
#        [3.5738421e-04],
#        [9.7546315e-01],
# ...
